# %%
# !git clone https://github.com/aub-mind/arabert
# Out:
# fatal: destination path 'arabert' already exists and is not an empty directory.

# %% [markdown]
# # Import Libraries

# %%
import os
import sys
import json
import nltk
import random
import logging
import pandas as pd
import tensorflow as tf

from glob import glob
from tqdm import  tqdm
from tensorflow.keras.utils import Progbar
from sklearn.model_selection import train_test_split

sys.path.append("arabert")
import arabert

from arabert import tokenization
from arabert import modeling

from transformers import AutoModelForTokenClassification, AutoTokenizer
import torch
# from arabert.run_classifier import input_fn_builder, model_fn_builder

# %%
# Input data pipeline config
TRAIN_BATCH_SIZE = 32 #@param {type:"integer"} #You can probably 
                                              #increase when using TPUS
MAX_SEQ_LENGTH = 512 #@param {type:"integer"} #reduce if running on GPU

# Training procedure config
EVAL_BATCH_SIZE = 64 
LEARNING_RATE = 2e-5
NUM_TRAIN_EPOCHS = 6 #@param {type:"integer"}
WARMUP_PROPORTION = 0.1 #@param {type:"number"}
NUM_TPU_CORES = 8
PREDICT_BATCH_SIZE = 8

# %% [markdown]
# # load data

# %%
data = pd.read_csv('trainingData.txt', sep=" ", header=None)

# %%
data
# Out:
#                 0      1
# 0             ففي      O
# 1           مسافه      O
# 2            3000      O
# 3             متر      O
# 4           موانع      O
# 5            خالف      O
# 6          العداء      O
# 7         المغربي      O
# 8             عبد  B-PER
# 9           الغني  I-PER
# 10            آيت  I-PER
# 11         باحماد  I-PER
# 12       التوقعات      O
# 13           التي      O
# 14           كانت      O
# 15          ترشحه      O
# 16          للفوز      O
# 17          باحدي      O
# 18     الميداليات      O
# 19         واكتفي      O
# 20       بالمرتبه      O
# 21        الرابعه      O
# 22             في      O
# 23       المسابقه      O
# 24       النهائيه      O
# 25           لهذه      O
# 26        المسافه      O
# 27          مسجلا      O
# 28          توقيت      O
# 29     8دو20ثو05ج      O
# ...           ...    ...
# 28386          في      O
# 28387        مطلع      O
# 28388     الاسبوع      O
# 28389      المقبل      O
# 28390         يضع      O
# 28391       الاطر      O
# 28392   القانونيه      O
# 28393     لاختيار      O
# 28394        رئيس      O
# 28395       وزراء      O
# 28396        مؤقت      O
# 28397      وحكومه      O
# 28398       تتولي      O
# 28399       قياده      O
# 28400      البلاد      O
# 28401        لحين      O
# 28402       اجراء      O
# 28403    انتخابات      O
# 28404        عامه      O
# 28405       الامم  B-ORG
# 28406     المتحده  I-ORG
# 28407          هي      O
# 28408       منظمه      O
# 28409      عالميه      O
# 28410       مكونه      O
# 28411          من      O
# 28412        جميع      O
# 28413         دول      O
# 28414      العالم      O
# 28415      تقريبا      O
#
# [28416 rows x 2 columns]

# %%
x = data.values[:,:-1]
y = data.values[:,-1]

# %%
x
# Out:
# array([['ففي'],
#        ['مسافه'],
#        ['3000'],
#        ...,
#        ['دول'],
#        ['العالم'],
#        ['تقريبا']], dtype=object)

# %%
y
# Out:
# array(['O', 'O', 'O', ..., 'O', 'O', 'O'], dtype=object)

# %% [markdown]
# # Create Model

# %%
# !pip install simpletransformers

# %% [markdown]
# # Using Simple Transformers

# %% [markdown]
# <a>https://towardsdatascience.com/simple-transformers-named-entity-recognition-with-transformer-models-c04b9242a2a0</a>
# this is a link to the tutorial

# %%
from simpletransformers.ner import NERModel
import simpletransformers

# Create a NERModel
model = NERModel('bert', 'bert-base-cased')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-29-ccfabc1bc100> in <module>
# ----> 1 from simpletransformers.ner import NERModel
#       2 import simpletransformers
#       3
#       4 # Create a NERModel
#       5 model = NERModel('bert', 'bert-base-cased')
#
# C:\ProgramData\Anaconda3\lib\site-packages\simpletransformers\ner\__init__.py in <module>
# ----> 1 from simpletransformers.ner.ner_model import NERModel
#
# C:\ProgramData\Anaconda3\lib\site-packages\simpletransformers\ner\ner_model.py in <module>
#      27 from torch.nn import CrossEntropyLoss
#      28 from torch.utils.data import DataLoader, RandomSampler, SequentialSampler, TensorDataset
# ---> 29 from transformers import (
#      30     WEIGHTS_NAME,
#      31     AdamW,
#
# ImportError: cannot import name 'ElectraConfig' from 'transformers' (C:\ProgramData\Anaconda3\lib\site-packages\transformers\__init__.py)

# %% [markdown]
# # Train the Model

# %%
model.train_model('trainingData.txt')
